# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from datetime import datetime, timedelta
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM
import yfinance as yf

# Fetch historical price data
# start_date = datetime.today() - timedelta(days=1460)
# end_date = datetime.today()
# df = yf.download("NATCOPHARM.NS", start=start_date, end=end_date)

start_date = datetime.today() - timedelta(days=2170)
end_date = datetime.today()

print(datetime.today() - timedelta(days=2170))
print(datetime.today())

df = yf.download("NATCOPHARM.NS", start=start_date, end=end_date)

# df = df[::-1]
df = df.reset_index()

# Calculate OHLC average
OHLC_avg = df[['Open', 'High', 'Low', 'Close']].mean(axis=1)

# Plot OHLC average

OHLC_avg.plot()
plt.show()

# Scaling the data
OHLC_avg_scaled = np.reshape(OHLC_avg.values, (len(OHLC_avg),1))
scaler = MinMaxScaler(feature_range=(0, 1))
OHLC_avg_scaled = scaler.fit_transform(OHLC_avg_scaled)

# Splitting the dataset into training and test sets
train_size = int(len(OHLC_avg_scaled) * 0.75)
test_size = len(OHLC_avg_scaled) - train_size
train_OHLC, test_OHLC = OHLC_avg_scaled[0:train_size,:], OHLC_avg_scaled[train_size:len(OHLC_avg_scaled),:]

# Function to create dataset with previous day's data used to predict the next day's data
def new_dataset(dataset, step_size):
    data_X, data_Y = [], []
    for i in range(len(dataset)-step_size-1):
        a = dataset[i:(i+step_size), 0]
        data_X.append(a)
        data_Y.append(dataset[i + step_size, 0])
    return np.array(data_X), np.array(data_Y)

# Creating train and test datasets
step_size = 1
trainX, trainY = new_dataset(train_OHLC, step_size)
testX, testY = new_dataset(test_OHLC, step_size)

# Reshaping the data for LSTM input
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# Model specification
model = Sequential()
model.add(LSTM(32, input_shape=(1, step_size), return_sequences=True))
model.add(LSTM(16))
model.add(Dense(1))

# Compiling the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Fitting the model
model.fit(trainX, trainY, epochs=5, batch_size=1, verbose=2)

# Making predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# Inverse scaling of predicted values
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# Calculating RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train RMSE: %.2f' % trainScore)

testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test RMSE: %.2f' % testScore)

# Plotting predicted values along with the original dataset
# plt.figure(figsize=(16, 8))  # Adjust size here
plt.plot(df.index[:train_size], OHLC_avg[:train_size], label='Original Data (Train)')
plt.plot(df.index[train_size:len(OHLC_avg)], OHLC_avg[train_size:len(OHLC_avg)], label='Original Data (Test)')
plt.plot(df.index[step_size:train_size-1], trainPredict, label='Train Predictions')
plt.plot(df.index[train_size+step_size:train_size+len(testPredict)+step_size], testPredict, label='Test Predictions')
plt.legend()
plt.show()

# Forecasting for the next 30 days
model_forecast = Sequential()
model_forecast.add(LSTM(32, input_shape=(1, step_size), return_sequences=True))
model_forecast.add(LSTM(16))
model_forecast.add(Dense(1))
model_forecast.compile(loss='mean_squared_error', optimizer='adam') 

new_OHLC_avg = OHLC_avg_scaled.copy()
print(new_OHLC_avg.shape)


for i in range(90):
    trainX_forecast, trainY_forecast = new_dataset(new_OHLC_avg, 1)
    trainX_forecast = np.reshape(trainX_forecast, (trainX_forecast.shape[0], 1, trainX_forecast.shape[1]))
    model_forecast.fit(trainX_forecast, trainY_forecast, epochs=5, batch_size=1, verbose=2)
    
    last_val = new_OHLC_avg[-1]
    next_val = model_forecast.predict(np.reshape(last_val, (1,1,1)))
    new_OHLC_avg = np.append(new_OHLC_avg, next_val[0])
    new_OHLC_avg = new_OHLC_avg.reshape(-1,1)
    print(new_OHLC_avg.shape)

# Inverse scaling of forecasted values
next_val = scaler.inverse_transform(new_OHLC_avg[-90:])
# next_val = scaler.inverse_transform(new_OHLC_avg[-90:])
print ("Next Day Value:", next_val)
# OHLC_avg=scaler.inverse_transform(OHLC_avg)

# df.set_index('Date', inplace=True)

# # Plotting original dataset with forecast values
# plt.figure(figsize=(20, 8))  # Adjust size here
# plt.plot(df.index, OHLC_avg, label='Original Data')
# plt.plot(pd.date_range(end=end_date, periods=7), forecast_values, label='Forecasted Values')
# plt.legend()
# plt.show()

# Plotting original dataset with forecast values
# plt.figure(figsize=(20, 8))  # Adjust size here
# plt.plot(df.index, OHLC_avg, label='Original Data')
# plt.plot(pd.date_range(end=end_date, periods=7), forecast_values[::-1], label='Forecasted Values')  # Reverse the forecasted values array
# plt.legend()
# plt.show()


s = range(len(OHLC_avg), len(OHLC_avg) + 90)
next_val = pd.DataFrame(next_val, index=list(s))
next_val.plot(figsize=(20,5), color='red', label='forecast')
plt.plot(OHLC_avg, 'g', label = 'original dataset')
plt.legend()
# Out:
# WARNING:tensorflow:From C:\Users\91908\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2018-03-26 13:43:12.205236
# 2024-03-04 13:43:12.205236
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\91908\AppData\Roaming\Python\Python39\site-packages\yfinance\utils.py:782: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# WARNING:tensorflow:From C:\Users\91908\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\91908\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\91908\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1098/1098 - 6s - loss: 0.0132 - 6s/epoch - 5ms/step
# Epoch 2/5
# 1098/1098 - 3s - loss: 6.5179e-04 - 3s/epoch - 3ms/step
# Epoch 3/5
# 1098/1098 - 3s - loss: 5.1800e-04 - 3s/epoch - 3ms/step
# Epoch 4/5
# 1098/1098 - 3s - loss: 5.0722e-04 - 3s/epoch - 3ms/step
# Epoch 5/5
# 1098/1098 - 3s - loss: 5.0962e-04 - 3s/epoch - 3ms/step
# 35/35 [==============================] - 1s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# Train RMSE: 13.53
# Test RMSE: 12.22
# (1467, 1)
# Epoch 1/5
# 1465/1465 - 8s - loss: 0.0116 - 8s/epoch - 5ms/step
# Epoch 2/5
# 1465/1465 - 4s - loss: 5.4242e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1465/1465 - 5s - loss: 4.7218e-04 - 5s/epoch - 3ms/step
# Epoch 4/5
# 1465/1465 - 5s - loss: 4.5981e-04 - 5s/epoch - 3ms/step
# Epoch 5/5
# 1465/1465 - 4s - loss: 4.5451e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 1s 767ms/step
# (1468, 1)
# Epoch 1/5
# 1466/1466 - 4s - loss: 4.3856e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1466/1466 - 4s - loss: 4.4914e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1466/1466 - 4s - loss: 4.7295e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1466/1466 - 4s - loss: 4.4759e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1466/1466 - 5s - loss: 4.6698e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 31ms/step
# (1469, 1)
# Epoch 1/5
# 1467/1467 - 4s - loss: 4.5351e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1467/1467 - 4s - loss: 4.6524e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1467/1467 - 4s - loss: 4.3969e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1467/1467 - 5s - loss: 4.4817e-04 - 5s/epoch - 3ms/step
# Epoch 5/5
# 1467/1467 - 4s - loss: 4.5158e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# (1470, 1)
# Epoch 1/5
# 1468/1468 - 4s - loss: 4.5303e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1468/1468 - 4s - loss: 4.4452e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1468/1468 - 4s - loss: 4.5241e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1468/1468 - 4s - loss: 4.5018e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1468/1468 - 4s - loss: 4.4019e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 42ms/step
# (1471, 1)
# Epoch 1/5
# 1469/1469 - 4s - loss: 4.1856e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 
-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1503/1503 - 4s - loss: 3.8008e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1503/1503 - 4s - loss: 3.7756e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 34ms/step
# (1506, 1)
# Epoch 1/5
# 1504/1504 - 4s - loss: 3.6598e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1504/1504 - 4s - loss: 3.9117e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1504/1504 - 4s - loss: 3.7414e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1504/1504 - 4s - loss: 3.8149e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1504/1504 - 4s - loss: 3.9340e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 35ms/step
# (1507, 1)
# Epoch 1/5
# 1505/1505 - 4s - loss: 3.7140e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1505/1505 - 6s - loss: 3.7607e-04 - 6s/epoch - 4ms/step
# Epoch 3/5
# 1505/1505 - 5s - loss: 3.7699e-04 - 5s/epoch - 4ms/step
# Epoch 4/5
# 1505/1505 - 6s - loss: 3.8079e-04 - 6s/epoch - 4ms/step
# Epoch 5/5
# 1505/1505 - 5s - loss: 3.7975e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 38ms/step
# (1508, 1)
# Epoch 1/5
# 1506/1506 - 5s - loss: 3.8220e-04 - 5s/epoch - 4ms/step
# Epoch 2/5
# 1506/1506 - 5s - loss: 3.7401e-04 - 5s/epoch - 3ms/step
# Epoch 3/5
# 1506/1506 - 5s - loss: 3.7365e-04 - 5s/epoch - 3ms/step
# Epoch 4/5
# 1506/1506 - 6s - loss: 3.8040e-04 - 6s/epoch - 4ms/step
# Epoch 5/5
# 1506/1506 - 6s - loss: 3.7667e-04 - 6s/epoch - 4ms/step
# 1/1 [==============================] - 0s 28ms/step
# (1509, 1)
# Epoch 1/5
# 1507/1507 - 5s - loss: 3.7768e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1507/1507 - 5s - loss: 3.8099e-04 - 5s/epoch - 4ms/step
# Epoch 3/5
# 1507/1507 - 5s - loss: 3.8613e-04 - 5s/epoch - 4ms/step
# Epoch 4/5
# 1507/1507 - 6s - loss: 3.8147e-04 - 6s/epoch - 4ms/step
# Epoch 5/5
# 1507/1507 - 5s - loss: 3.8172e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 31ms/step
# (1510, 1)
# Epoch 1/5
# 1508/1508 - 4s - loss: 3.7965e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1508/1508 - 4s - loss: 3.8490e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1508/1508 - 5s - loss: 3.7794e-04 - 5s/epoch - 3ms/step
# Epoch 4/5
# 1508/1508 - 4s - loss: 3.7696e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1508/1508 - 4s - loss: 3.7359e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 27ms/step
# (1511, 1)
# Epoch 1/5
# 1509/1509 - 4s - loss: 3.8002e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1509/1509 - 4s - loss: 3.8212e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1509/1509 - 4s - loss: 3.7848e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1509/1509 - 4s - loss: 3.6942e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1509/1509 - 4s - loss: 3.9113e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 26ms/step
# (1512, 1)
# Epoch 1/5
# 1510/1510 - 4s - loss: 3.6831e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1510/1510 - 4s - loss: 3.7893e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1510/1510 - 6s - loss: 3.8451e-04 - 6s/epoch - 4ms/step
# Epoch 4/5
# 1510/1510 - 4s - loss: 3.7293e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1510/1510 - 5s - loss: 3.6613e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 29ms/step
# (1513, 1)
# Epoch 1/5
# 1511/1511 - 5s - loss: 3.8368e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1511/1511 - 4s - loss: 3.7475e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1511/1511 - 4s - loss: 3.7591e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1511/1511 - 4s - loss: 3.7831e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1511/1511 - 5s - loss: 3.7265e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 39ms/step
# (1514, 1)
# Epoch 1/5
# 1512/1512 - 5s - loss: 3.7670e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1512/1512 - 5s - loss: 3.7504e-04 - 5s/epoch - 3ms/step
# Epoch 3/5
# 1512/1512 - 4s - loss: 3.7522e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1512/1512 - 4s - loss: 3.8089e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1512/1512 - 4s - loss: 3.7426e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 43ms/step
# (1515, 1)
# Epoch 1/5
# 1513/1513 - 4s - loss: 3.7792e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1513/1513 - 4s - loss: 3.6978e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1513/1513 - 6s - loss: 3.7303e-04 - 6s/epoch - 4ms/step
# Epoch 4/5
# 1513/1513 - 4s - loss: 3.8194e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1513/1513 - 4s - loss: 3.8078e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 32ms/step
# (1516, 1)
# Epoch 1/5
# 1514/1514 - 4s - loss: 3.7410e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1514/1514 - 4s - loss: 3.8296e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1514/1514 - 4s - loss: 3.6894e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1514/1514 - 4s - loss: 3.7416e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1514/1514 - 4s - loss: 3.7223e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 40ms/step
# (1517, 1)
# Epoch 1/5
# 1515/1515 - 5s - loss: 3.7878e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1515/1515 - 5s - loss: 3.6258e-04 - 5s/epoch - 3ms/step
# Epoch 3/5
# 1515/1515 - 5s - loss: 3.7861e-04 - 5s/epoch - 3ms/step
# Epoch 4/5
# 1515/1515 - 4s - loss: 3.7704e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1515/1515 - 5s - loss: 3.7278e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 35ms/step
# (1518, 1)
# Epoch 1/5
# 1516/1516 - 5s - loss: 3.8188e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1516/1516 - 4s - loss: 3.7200e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1516/1516 - 4s - loss: 3.8433e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1516/1516 - 4s - loss: 3.7848e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1516/1516 - 4s - loss: 3.7525e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 31ms/step
# (1519, 1)
# Epoch 1/5
# 1517/1517 - 4s - loss: 3.7805e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1517/1517 - 4s - loss: 3.7245e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1517/1517 - 4s - loss: 3.8270e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1517/1517 - 4s - loss: 3.6641e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1517/1517 - 4s - loss: 3.7881e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 27ms/step
# (1520, 1)
# Epoch 1/5
# 1518/1518 - 4s - loss: 3.7238e-04 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1518/1518 - 4s - loss: 3.7565e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1518/1518 - 4s - loss: 3.7744e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1518/1518 - 4s - loss: 3.7119e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1518/1518 - 4s - loss: 3.7230e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 27ms/step
# (1521, 1)
# Epoch 1/5
# 1519/1519 - 4s - loss: 3.7908e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1519/1519 - 5s - loss: 3.7874e-04 - 5s/epoch - 4ms/step
# Epoch 3/5
# 1519/1519 - 5s - loss: 3.7590e-04 - 5s/epoch - 4ms/step
# Epoch 4/5
# 1519/1519 - 5s - loss: 3.7524e-04 - 5s/epoch - 4ms/step
# Epoch 5/5
# 1519/1519 - 6s - loss: 3.6571e-04 - 6s/epoch - 4ms/step
# 1/1 [==============================] - 0s 35ms/step
# (1522, 1)
# Epoch 1/5
# 1520/1520 - 4s - loss: 3.7694e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1520/1520 - 5s - loss: 3.6927e-04 - 5s/epoch - 3ms/step
# Epoch 3/5
# 1520/1520 - 5s - loss: 3.7359e-04 - 5s/epoch - 3ms/step
# Epoch 4/5
# 1520/1520 - 5s - loss: 3.7497e-04 - 5s/epoch - 3ms/step
# Epoch 5/5
# 1520/1520 - 4s - loss: 3.8138e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 32ms/step
# (1523, 1)
# Epoch 1/5
# 1521/1521 - 4s - loss: 3.6301e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1521/1521 - 4s - loss: 3.7859e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1521/1521 - 4s - loss: 3.6422e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1521/1521 - 4s - loss: 3.6782e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1521/1521 - 4s - loss: 3.7594e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 29ms/step
# (1524, 1)
# Epoch 1/5
# 1522/1522 - 5s - loss: 3.7230e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1522/1522 - 5s - loss: 3.7422e-04 - 5s/epoch - 3ms/step
# Epoch 3/5
# 1522/1522 - 5s - loss: 3.7189e-04 - 5s/epoch - 3ms/step
# Epoch 4/5
# 1522/1522 - 5s - loss: 3.7129e-04 - 5s/epoch - 3ms/step
# Epoch 5/5
# 1522/1522 - 5s - loss: 3.6786e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1535/1535 - 4s - loss: 3.7301e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1535/1535 - 4s - loss: 3.6576e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1535/1535 - 4s - loss: 3.7023e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1535/1535 - 4s - loss: 3.6302e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 33ms/step
# (1538, 1)
# Epoch 1/5
# 1536/1536 - 4s - loss: 3.7572e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1536/1536 - 4s - loss: 3.6780e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1536/1536 - 4s - loss: 3.6933e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1536/1536 - 5s - loss: 3.6011e-04 - 5s/epoch - 3ms/step
# Epoch 5/5
# 1536/1536 - 4s - loss: 3.6320e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 31ms/step
# (1539, 1)
# Epoch 1/5
# 1537/1537 - 4s - loss: 3.6878e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1537/1537 - 5s - loss: 3.5904e-04 - 5s/epoch - 3ms/step
# Epoch 3/5
# 1537/1537 - 4s - loss: 3.7174e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1537/1537 - 4s - loss: 3.6402e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1537/1537 - 4s - loss: 3.7042e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# (1540, 1)
# Epoch 1/5
# 1538/1538 - 4s - loss: 3.7694e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1538/1538 - 4s - loss: 3.6853e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1538/1538 - 4s - loss: 3.6287e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1538/1538 - 4s - loss: 3.6000e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1538/1538 - 4s - loss: 3.5855e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 26ms/step
# (1541, 1)
# Epoch 1/5
# 1539/1539 - 4s - loss: 3.6495e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1539/1539 - 4s - loss: 3.6604e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1539/1539 - 4s - loss: 3.6738e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1539/1539 - 4s - loss: 3.6507e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1539/1539 - 4s - loss: 3.6273e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 28ms/step
# (1542, 1)
# Epoch 1/5
# 1540/1540 - 4s - loss: 3.6289e-04 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1540/1540 - 4s - loss: 3.5848e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1540/1540 - 4s - loss: 3.6428e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1540/1540 - 4s - loss: 3.5803e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1540/1540 - 4s - loss: 3.5847e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 29ms/step
# (1543, 1)
# Epoch 1/5
# 1541/1541 - 4s - loss: 3.6130e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1541/1541 - 4s - loss: 3.6427e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1541/1541 - 4s - loss: 3.6898e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1541/1541 - 4s - loss: 3.5806e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1541/1541 - 4s - loss: 3.6809e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# (1544, 1)
# Epoch 1/5
# 1542/1542 - 4s - loss: 3.6233e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1542/1542 - 4s - loss: 3.5972e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1542/1542 - 4s - loss: 3.5884e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1542/1542 - 4s - loss: 3.6415e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1542/1542 - 4s - loss: 3.5988e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 33ms/step
# (1545, 1)
# Epoch 1/5
# 1543/1543 - 5s - loss: 3.6311e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1543/1543 - 5s - loss: 3.6133e-04 - 5s/epoch - 4ms/step
# Epoch 3/5
# 1543/1543 - 4s - loss: 3.6384e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1543/1543 - 4s - loss: 3.7013e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1543/1543 - 5s - loss: 3.5728e-04 - 5s/epoch - 3ms/step
# 1/1 [==============================] - 0s 27ms/step
# (1546, 1)
# Epoch 1/5
# 1544/1544 - 4s - loss: 3.5747e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1544/1544 - 4s - loss: 3.5932e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1544/1544 - 4s - loss: 3.6331e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1544/1544 - 4s - loss: 3.5938e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1544/1544 - 4s - loss: 3.6041e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 28ms/step
# (1547, 1)
# Epoch 1/5
# 1545/1545 - 4s - loss: 3.5870e-04 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1545/1545 - 4s - loss: 3.6372e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1545/1545 - 4s - loss: 3.5730e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1545/1545 - 4s - loss: 3.6549e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1545/1545 - 4s - loss: 3.6078e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# (1548, 1)
# Epoch 1/5
# 1546/1546 - 4s - loss: 3.6110e-04 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1546/1546 - 4s - loss: 3.5821e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1546/1546 - 4s - loss: 3.6616e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1546/1546 - 4s - loss: 3.6449e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1546/1546 - 4s - loss: 3.5928e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 44ms/step
# (1549, 1)
# Epoch 1/5
# 1547/1547 - 5s - loss: 3.6429e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1547/1547 - 4s - loss: 3.5905e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1547/1547 - 4s - loss: 3.5452e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1547/1547 - 5s - loss: 3.7719e-04 - 5s/epoch - 3ms/step
# Epoch 5/5
# 1547/1547 - 4s - loss: 3.6058e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 28ms/step
# (1550, 1)
# Epoch 1/5
# 1548/1548 - 4s - loss: 3.6385e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1548/1548 - 4s - loss: 3.5755e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1548/1548 - 4s - loss: 3.6476e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1548/1548 - 4s - loss: 3.5946e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1548/1548 - 4s - loss: 3.6223e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 30ms/step
# (1551, 1)
# Epoch 1/5
# 1549/1549 - 4s - loss: 3.6010e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1549/1549 - 4s - loss: 3.5961e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1549/1549 - 4s - loss: 3.5712e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1549/1549 - 5s - loss: 3.5317e-04 - 5s/epoch - 3ms/step
# Epoch 5/5
# 1549/1549 - 4s - loss: 3.6554e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 31ms/step
# (1552, 1)
# Epoch 1/5
# 1550/1550 - 4s - loss: 3.5551e-04 - 4s/epoch - 3ms/step
# Epoch 2/5
# 1550/1550 - 4s - loss: 3.5744e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1550/1550 - 4s - loss: 3.5900e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1550/1550 - 4s - loss: 3.6421e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1550/1550 - 4s - loss: 3.6357e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 27ms/step
# (1553, 1)
# Epoch 1/5
# 1551/1551 - 4s - loss: 3.5820e-04 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1551/1551 - 4s - loss: 3.5411e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1551/1551 - 4s - loss: 3.6797e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1551/1551 - 4s - loss: 3.6056e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1551/1551 - 4s - loss: 3.6131e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 30ms/step
# (1554, 1)
# Epoch 1/5
# 1552/1552 - 4s - loss: 3.5471e-04 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1552/1552 - 4s - loss: 3.6925e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1552/1552 - 4s - loss: 3.5951e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1552/1552 - 4s - loss: 3.5224e-04 - 4s/epoch - 2ms/step
# Epoch 5/5
# 1552/1552 - 4s - loss: 3.5595e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# (1555, 1)
# Epoch 1/5
# 1553/1553 - 4s - loss: 3.6013e-04 - 4s/epoch - 2ms/step
# Epoch 2/5
# 1553/1553 - 4s - loss: 3.6514e-04 - 4s/epoch - 2ms/step
# Epoch 3/5
# 1553/1553 - 4s - loss: 3.6006e-04 - 4s/epoch - 2ms/step
# Epoch 4/5
# 1553/1553 - 4s - loss: 3.5429e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1553/1553 - 4s - loss: 3.5893e-04 - 4s/epoch - 3ms/step
# 1/1 [==============================] - 0s 33ms/step
# (1556, 1)
# Epoch 1/5
# 1554/1554 - 5s - loss: 3.6069e-04 - 5s/epoch - 3ms/step
# Epoch 2/5
# 1554/1554 - 4s - loss: 3.5155e-04 - 4s/epoch - 3ms/step
# Epoch 3/5
# 1554/1554 - 4s - loss: 3.6193e-04 - 4s/epoch - 3ms/step
# Epoch 4/5
# 1554/1554 - 4s - loss: 3.5583e-04 - 4s/epoch - 3ms/step
# Epoch 5/5
# 1554/1554 - 4s - loss: 3.5453e-04 - 4s/epoch - 2ms/step
# 1/1 [==============================] - 0s 29ms/step
# (1557, 1)
# Next Day Value: [[986.60748822]
#  [997.74494857]
#  [991.46599142]
#  [991.6774253 ]
#  [986.03352989]
#  [987.7076454 ]
#  [977.71586364]
#  [990.52549702]
#  [977.17214032]
#  [977.72494259]
#  [982.6656208 ]
#  [972.46827481]
#  [958.26694451]
#  [970.75547877]
#  [960.87302442]
#  [963.81831911]
#  [955.21532057]
#  [959.43137218]
#  [963.826089  ]
#  [962.63594469]
#  [958.3773276 ]
#  [960.5343586 ]
#  [958.82139366]
#  [965.54399458]
#  [967.10405318]
#  [961.25265107]
#  [963.60304251]
#  [957.20027386]
#  [954.35206056]
#  [948.21684635]
#  [942.4812747 ]
#  [947.86665239]
#  [938.61773959]
#  [941.12699148]
#  [941.86086595]
#  [943.21265774]
#  [946.50877982]
#  [941.31545352]
#  [938.72115512]
#  [944.59916066]
#  [945.71844697]
#  [945.80653386]
#  [952.73372779]
#  [944.91417899]
#  [940.53424185]
#  [937.27924951]
#  [942.83159536]
#  [948.67011804]
#  [945.55945984]
#  [942.8974705 ]
#  [943.83593797]
#  [940.92484769]
#  [940.03025475]
#  [931.08825257]
#  [923.85486589]
#  [926.00286017]
#  [934.00103197]
#  [933.91112928]
#  [941.68266524]
#  [952.1905112 ]
#  [951.58526218]
#  [949.27448028]
#  [948.68160396]
#  [946.39392059]
#  [941.02023996]
#  [938.89775119]
#  [931.02909162]
#  [923.09244553]
#  [918.94746307]
#  [921.39801852]
#  [921.06078844]
#  [924.69004451]
#  [922.9140759 ]
#  [917.54085978]
#  [917.79008742]
#  [913.3581258 ]
#  [912.32131011]
#  [912.08724221]
#  [909.64901723]
#  [911.66804825]
#  [910.75251039]
#  [908.8588533 ]
#  [907.44595809]
#  [908.53454488]
#  [905.48794604]
#  [905.67404333]
#  [901.89204982]
#  [901.82710368]
#  [897.72536235]
#  [891.64698657]]
